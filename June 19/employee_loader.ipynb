# %%
employee_data = [
    (101, "Rahul", "HR", 45000),
    (102, "Anita", "IT", 60000),
    (103, "Kiran", "Finance", 55000),
    (104, "Priya", "Sales", 50000),
    (105, "Arun", "IT", 70000)
]

# %%
columns = ["emp_id", "name", "department", "salary"]

df = spark.createDataFrame(employee_data, columns)

# %%
df.show()
# Out:
# +------+-----+----------+------+
# |emp_id| name|department|salary|
# +------+-----+----------+------+
# |   101|Rahul|        HR| 45000|
# |   102|Anita|        IT| 60000|
# |   103|Kiran|   Finance| 55000|
# |   104|Priya|     Sales| 50000|
# |   105| Arun|        IT| 70000|
# +------+-----+----------+------+

# %%
print("Employee Load Completed")
# Out:
# Employee Load Completed
